# %% [markdown]
# # Shelf filters

# %%
from shelving import Class_IIR_Shelving

from IPython.display import display, Image

# %%
display(Image(url='https://s3.amazonaws.com/embeddedrelated/user/1/shelving_97220.jpg', width=500))
# Out:
# <img src="https://s3.amazonaws.com/embeddedrelated/user/1/shelving_97220.jpg" width="500"/>

# %%
# high shelf filter sample 
iir_LS1 = Class_IIR_Shelving( fc=50, G=-20, Q=0.75, fs=44100, shelf_type='Base_Shelf')
# draw frequency response
iir_LS1.f_show(8192)
# Out:
# 3.141209158392822 0.0
